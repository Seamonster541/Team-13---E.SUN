# %% [markdown]
# # IMPORTS HERE

# %%
import pandas as pd

# %% [markdown]
# # Data Preparation

# %%
# Loads CSV file
df = pd.read_csv('data/dataset_1st/public_processed.csv')

# %%
df
# Out:
#                                                     txkey  locdt   loctm  \
# 0       a2c1209018e4e52e04f6fabb48f05f1b8bc09dc838ff6c...     56  105157
# 1       16c4880500059e01553789be11bbb50753b7acaae7b95b...     56  185520
# 2       623c56be3bee87724e3d119c271d9ed098eeda84233183...     59  102312
# 3       250da12187059cf6e3a3066656a2919d08ceb8207efd55...     58  230138
# 4       4b268e0da036f44cbbb056ddfac6a28ea336d9cf299843...     59  101937
# ...                                                   ...    ...     ...
# 600177  741a391b2c2114491d1d18acb1a892341b9280e1e3529f...     56   93445
# 600178  76f613595631fb35938bf10f5b7abe3f60a3d34ccf5f44...     56  145420
# 600179  c32e846a4469e4869e2df8f8e160fba4e829b6beebb44d...     58    3400
# 600180  d641cd25a830de759cd55b4a643d71eadb770bc917aed3...     59  134901
# 600181  301d0262bdd594a886446ddca09b4a21bef51dddf9618a...     56  220238
#
#                                                      chid  \
# ...

# %%
df.describe()
# Out:
#                locdt          loctm          contp          etymd  \
# count  600182.000000  600182.000000  600182.000000  586356.000000
# mean       57.474441  142866.065697       4.896951       4.727415
# std         1.107709   54591.701218       0.469987       2.285876
# min        56.000000       0.000000       0.000000       0.000000
# 25%        56.000000  103505.000000       5.000000       4.000000
# 50%        57.000000  144919.000000       5.000000       5.000000
# 75%        58.000000  185435.000000       5.000000       5.000000
# max        59.000000  235959.000000       6.000000      10.000000
#
#                  mcc         conam           ecfg          insfg  \
# count  599828.000000  6.001820e+05  600182.000000  600182.000000
# mean      318.183049  1.572936e+03       0.601961       0.011681
# std        70.003680  1.165056e+04       0.489494       0.107448
# min         0.000000  0.000000e+00       0.000000       0.000000
# ...
